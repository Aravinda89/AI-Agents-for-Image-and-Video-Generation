# %% [markdown]
# # L6: Building a Video Agent

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
import warnings
warnings.filterwarnings("ignore", message=".*non-text parts.*")
warnings.filterwarnings("ignore")

import json
import time
from google import genai
from google.genai import types
from google.genai.types import (
    GenerateVideosConfig,
    GenerateContentConfig,
)
from google.genai import types as genai_types
from IPython.display import (
    display,
    Video,
    Image as IPImage,
)

# %%
import os
from helper import authenticate

credentials, project_id = authenticate()

client = genai.Client(
    project=project_id,
    location="global",
    credentials=credentials,
    http_options=types.HttpOptions(
         base_url=os.getenv("GOOGLE_VERTEX_BASE_URL")
    )
)

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
# </div>

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different run results:</b> The output generated by AI models, and agents can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %%
MODEL = "gemini-3.1-pro-preview"
IMAGE_MODEL = "gemini-3.1-flash-image-preview"
VIDEO_MODEL = "veo-3.1-fast-generate-001"

# %%
VOICE_PROFILE = (
  """calm, clear, male voice with a neutral American accent.
     Warm baritone, steady pace around 140 words per minute.
     Professional and conversational, like a senior engineer explaining"
     to a colleague. No uptalk, no vocal fry. Even tone
     throughout, slight emphasis on key technical terms.
     Natural pauses between sentences."""
)

STYLE_PREFIX = (
  """Technical diagram on a dark navy background. Minimal flat design,
     sans-serif labels. 16:9 aspect ratio."""
)

# %% [markdown]
# ## Tool 1: `plan_scenes`

# %%
def plan_scenes(brief: str, num_scenes: int = 3) -> list:
    """Break a text brief into scene plans."""
    
    prompt = f"""
    Break this into {num_scenes} scenes for an explainer video.
    Brief: {brief}
    VOICE STYLE INSTRUCTIONS:
    Calm, clear, male voice with a neutral American accent. Warm baritone, 
    steady pace around 140 words per minute.
    Professional and conversational, like a senior engineer explaining to a 
    colleague. 
    No uptalk, no vocal fry. Even tone throughout, slight emphasis on key 
    technical terms. 
    Natural pauses between sentences.
    For each scene, return a JSON array where each element has:
    - visual_description: describe a clean diagram layout
    - narration_script: exactly ~20 words spoken in 8 seconds
    - camera_motion: one of [slow_left_to_right, slow_zoom_in, slow_zoom_out, static]
    Return ONLY the JSON array, no markdown.
    """.strip()

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt,
    )
    
    text = response.text.strip()
    
    # Clean up potential markdown formatting from the response
    if text.startswith("```"):
        text = text.split("\n", 1)[1].rsplit("```", 1)[0]
    
    scenes = json.loads(text)
    
    for scene in scenes:
        scene["voice_profile"] = VOICE_PROFILE
        for key, val in scene.items():
            if isinstance(val, str):
                scene[key] = clean(val)
                
    return scenes

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Please wait:</b> This cell may take a minute to run.</p>

# %%
from helper import clean

brief = (
    """Explain how RAG works -embedding the query, retrieving relevant documents,
    and generating a grounded answer."""
)

scene_plans = plan_scenes(brief)

# %%
for i, scene in enumerate(scene_plans):
    print(f"\n--- Scene {i+1} ---")
    desc = scene['visual_description']
    print(f"Visual:    {desc[:70]}...")
    narr = scene['narration_script']
    print(f"Narration: {narr}")
    cam = scene['camera_motion']
    print(f"Camera:    {cam}")
# Out:
# --- Scene 1 ---
# Visual:    A clean diagram showing a text bubble labeled 'Query' transforming int...
# Narration: First, the system converts your user query into a mathematical embedding vector, which captures its exact semantic meaning and intent.
# Camera:    slow_zoom_in
#
# --- Scene 2 ---
# Visual:    The embedding vector moves rightward into a sleek database cylinder ic...
# Narration: Next, this vector searches through a vector database, rapidly retrieving the most relevant documents that match your original search question.
# Camera:    slow_left_to_right
#
# --- Scene 3 ---
# Visual:    The original query and retrieved document icons merge into a central p...
# Narration: Finally, the language model combines these retrieved documents with your query to generate a highly accurate and fully grounded answer.
# Camera:    slow_zoom_out

# %% [markdown]
# ## Tool 2: `generate_scene_image`

# %%
from helper import extract_image

def generate_scene_image(
    visual_description: str,
    scene_num: int = 1,
) -> str:
    """Generate a reference frame. Returns file path."""
    
    response = client.models.generate_content(
        model=IMAGE_MODEL,
        contents=(
            STYLE_PREFIX
            + clean(visual_description)
        ),
        config=GenerateContentConfig(
            response_modalities=[
                "IMAGE", "TEXT"
            ],
        ),
    )
    img = extract_image(response)
    if img is None:
        raise ValueError(
            "No image returned"
        )
    path = f"scene_{scene_num}_ref.png"
    img.save(path)
    print("Reference frame for scene {scene_num}:")
    display(IPImage(filename=path, width=400))
    return path

# %% [markdown]
# ## Tool 3: `generate_scene_video`

# %%
def generate_scene_video(
    image_path: str,
    prompt: str,
    narration: str,
    voice_profile: str,
    scene_num: int = 1,
    timeout: int = 300,
) -> str:
    """Animate a reference frame into an 8s video with narration."""
    with open(image_path, "rb") as f:
        image_bytes = f.read()

    image_obj = genai_types.Image(
        image_bytes=image_bytes,
        mime_type="image/png",
    )

    full_prompt = (
        f"{clean(prompt)}\n\n"
        "Narration spoken in a"
        f" {clean(voice_profile)}:\n"
        f'\"{clean(narration)}\"'
    )

    operation = (
        client.models.generate_videos(
            model=VIDEO_MODEL,
            image=image_obj,
            prompt=full_prompt,
            config=GenerateVideosConfig(
                aspect_ratio="16:9",
                number_of_videos=1,
                duration_seconds=8,
                generate_audio=True,
            ),
        )
    )

    print(f"Operation: {operation.name}")
    start = time.time()

    while not operation.done:
        elapsed = int(
            time.time() - start
        )
        if elapsed > timeout:
            raise TimeoutError(
                "Veo timed out after"
                f" {timeout}s."
            )
        time.sleep(20)
        operation = (
            client.operations.get(operation)
        )
        print("  Processing..."f" ({elapsed}s elapsed)")

    video = (
        operation.result
        .generated_videos[0]
    )
    path = f"scene_{scene_num}.mp4"
    with open(path, "wb") as f:
        f.write(video.video.video_bytes)

    duration = int(time.time() - start)
    print(
        f"Scene {scene_num} video"
        f" ready ({duration}s):"
    )
    display(Video(path, embed=True, width=480, height=270))
    return path

# %% [markdown]
# ## Tool 4: `evaluate_scene`

# %%
def evaluate_scene(
    video_path: str,
    original_prompt: str,
    narration_script: str = "",
    threshold: float = 3.0,
) -> dict:
    """Score a video clip on multiple criteria using Gemini."""
    from google.genai.types import Part

    with open(video_path, "rb") as f:
        video_bytes = f.read()

    video_part = Part.from_bytes(
        data=video_bytes,
        mime_type="video/mp4",
    )

    if narration_script:
        narration_check = (
            "- narration_alignment: the spoken audio matches this expected narration:"
            f' \"{narration_script}\". Score 1 if the spoken words are completely'
            " different, incoherent, or unrecognizable."
        )
    else:
        narration_check = "- narration_sync: audio pacing matches visual flow"

    eval_prompt = (
        "Watch this 8-second video clip carefully.\n\n"
        f"It was generated from this prompt: {original_prompt}\n\n"
        "Score each criterion from 1 (poor) to 5 (excellent):\n"
        "- temporal_consistency: objects coherent across frames\n"
        "- motion_coherence: camera matches prompt direction\n"
        "- prompt_adherence: visuals match scene description\n"
        "- visual_quality: sharp, no artifacts or distortion\n"
        f"{narration_check}\n"
        "- voice_profile: voice tone and pace match professional narration\n"
        "- scene_continuity: visual style is consistent\n\n"
        f"Also classify the failure type if overall < {threshold}:\n"
        '- \"visual\" if the issue is with image quality or style\n'
        '- \"audio\" if the issue is with narration alignment or voice\n'
        '- \"none\" if the clip passes\n\n'
        "Return ONLY a JSON object:\n"
        "{\n"
        '  \"scores\": {\"criterion_name\": score},\n'
        '  \"overall\": <average>,\n'
        f'  \"pass\": <true if overall >= {threshold}>,\n'
        '  \"failure_type\": \"visual\" | \"audio\" | \"none\",\n'
        '  \"feedback\": \"<improvements if fail, else OK>\"\n'
        "}"
    )

    response = client.models.generate_content(
        model=MODEL,
        contents=[video_part, eval_prompt],
    )

    text = response.text.strip()

    if not text:
        return {
            "overall": 0,
            "pass": False,
            "failure_type": "audio",
            "feedback": "Empty response",
            "scores": {},
        }

    if text.startswith("```"):
        text = text.split("\n", 1)[1].rsplit("```", 1)[0]

    result = json.loads(text)
    result["pass"] = result["overall"] >= threshold

    narr_score = result["scores"].get("narration_alignment", result["scores"].get("narration_sync", 5))

    if narr_score < 3:
        result["pass"] = False
        result["failure_type"] = "audio"
        result["feedback"] = result["feedback"] + " Narration does not match the expected script."

    overall = result['overall']
    print(f"   Overall:      {overall:.1f}")
    passed = result['pass']
    print(f"   Pass:         {passed}")
    ftype = result['failure_type']
    print(f"   Failure type: {ftype}")
    fb = result['feedback']
    print(f"   Feedback:     {fb}")

    if not result['pass']:
        step = 'image' if ftype == 'visual' else 'video'
        print(f"   -> Agent will retry from {step} step")

    return result

# %% [markdown]
# ## Wiring the Agent

# %%
CORRUPTED_NARRATION = (
    """The quantum blockchain leverages distributed photon matrices to 
    synergize cross-dimensional neural pathways."""
)

print("Corrupted narration for scene 1:")
print(CORRUPTED_NARRATION)
print()
print("Real narration for scene 1:")
print(
    [0]["narration_script"]
)
# Out:
# Corrupted narration for scene 1:
# The quantum blockchain leverages distributed photon matrices to
#     synergize cross-dimensional neural pathways.
#
# Real narration for scene 1:
# First, the system converts your user query into a mathematical embedding vector, which captures its exact semantic meaning and intent.

# %%
from helper import make_display_tool
from google.adk import Agent

plan_scenes_tool = make_display_tool(
    plan_scenes
)
generate_scene_image_tool = (
    make_display_tool(generate_scene_image)
)
generate_scene_video_tool = (
    make_display_tool(generate_scene_video)
)
evaluate_scene_tool = make_display_tool(
    evaluate_scene
)

PLANS_JSON = json.dumps(
    scene_plans, indent=2
)
CORRUPT = CORRUPTED_NARRATION

# %%
SYSTEM_PROMPT = (
    "You are a video production agent.\n"
    "Your goal is to produce a high-quality video for every scene in the plan below.\n\n"
    "Scene plans:\n"
    f"{PLANS_JSON}\n\n"
    "You have three tools: generate_scene_image, generate_scene_video, and evaluate_scene.\n\n"
    "Process ONE scene at a time. Do NOT batch. Always evaluate after generating a video."
    " Do not move to the next scene until the current one passes.\n\n"
    "For scene 1 only, on the FIRST generate_scene_video call, use this corrupted audio"
    " instead of the real one:\n"
    f'"{CORRUPT}"\n'
    "On any retry of scene 1, use the real narration_script from the plan.\n\n"
    "For all other scenes, always use the real narration_script.\n\n"
    "When calling evaluate_scene, always pass the REAL narration_script from the scene plan.\n\n"
    "If evaluation fails:\n"
    "- failure_type 'audio': regenerate the video only, reuse the same image.\n"
    "- failure_type 'visual': regenerate both the image and the video.\n\n"
    "Maximum 1 retry per scene. After all scenes pass, list the video file paths."
)

# %%
from google.adk.models import Gemini

class DLAIGemini(Gemini):
    _client: genai.Client = None  # class-level cache
    
    @property
    def api_client(self) -> genai.Client:
        if self._client is None:
            self._client = genai.Client(
                project=project_id,
                location="global",
                credentials=credentials,
                http_options=types.HttpOptions(
                    base_url=os.getenv("GOOGLE_VERTEX_BASE_URL")
                )
            )
        return self._client
        
agent = Agent(
    name="video_agent",
    model=DLAIGemini(model=MODEL),
    tools=[
        generate_scene_image_tool,
        generate_scene_video_tool,
        evaluate_scene_tool,
    ],
    instruction=SYSTEM_PROMPT,
)

print("Agent ready.")
# Out:
# Agent ready.

# %%
from google.adk.runners import Runner
from google.adk.sessions import (
    InMemorySessionService,
)

session_service = InMemorySessionService()

runner = Runner(
    agent=agent,
    app_name="video_agent",
    session_service=session_service,
)

session = await session_service.create_session(
    app_name="video_agent",
    user_id="user",
)

message = genai_types.Content(
    role="user",
    parts=[
        genai_types.Part(
            text="Start video production."
        )
    ],
)

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Please wait:</b> This cell may take a few minutes to run.</p>

# %%
print("Running agent - ~10 min for 3 scenes...")
print("Scene 1 will generate with wrong narration. Listen for the bad audio, then watch the agent fix it.\n")

async for event in runner.run_async(
    user_id="user",
    session_id=session.id,
    new_message=message,
):
    if event.is_final_response():
        print("\n--- Agent complete ---")
        if event.content and event.content.parts:
            for part in event.content.parts:
                if part.text:
                    print(part.text)
# Out:
# Running agent - ~10 min for 3 scenes...
# Scene 1 will generate with wrong narration. Listen for the bad audio, then watch the agent fix it.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# >> generate_scene_image
# Reference frame for scene {scene_num}:
#    Done in 10.3s
#
# >> generate_scene_video
# Operation: projects/dlai-gen-media/locations/global/publishers/google/models/veo-3.1-fast-generate-001/operations/394a2898-0665-4efd-8eb4-482cc8eb897c
#   Processing... (0s elapsed)
#   Processing... (30s elapsed)
#   Processing... (61s elapsed)
#   Processing... (92s elapsed)
#   Processing... (122s elapsed)
#   Processing... (153s elapsed)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       1 print("Running agent - ~10 min for 3 scenes...")
#       2 print("Scene 1 will generate with wrong narration. Listen for the bad audio, then watch the agent fix it.\n")
#       3
# ----> 4 async for event in runner.run_async(
#       5     user_id="user",
#       6     session_id=session.id,
#       7     new_message=message,
#
# File /usr/local/lib/python3.11/site-packages/google/adk/runners.py:631, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     623       await _run_compaction_for_sliding_window(
#     624           self.app,
#     625           session,
#     626           self.session_service,
#     627           skip_token_compaction=invocation_context.token_compaction_checked,
#     628       )
#     630 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 631   async for event in agen:
#     632     yield event
#
# File /usr/local/lib/python3.11/site-packages/google/adk/runners.py:616, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     606       yield event
#     608 async with Aclosing(
#     609     self._exec_with_plugin(
#     610         invocation_context=invocation_context,
#    (...)    614     )
#     615 ) as agen:
# --> 616   async for event in agen:
#     617     yield event
#     618 # Run compaction after all events are yielded from the agent.
#     619 # (We don't compact in the middle of an invocation, we only compact at
#     620 # the end of an invocation.)
#
# File /usr/local/lib/python3.11/site-packages/google/adk/runners.py:892, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     889 is_transcribing: bool = False
#     891 async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 892   async for event in agen:
#     893     _apply_run_config_custom_metadata(
#     894         event, invocation_context.run_config
#     895     )
#     896     # Step 3: Run the on_event callbacks before persisting so callback
#     897     # changes are stored in the session and match the streamed event.
#
# File /usr/local/lib/python3.11/site-packages/google/adk/runners.py:605, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     603 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     604   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 605     async for event in agen:
#     606       yield event
#
# File /usr/local/lib/python3.11/site-packages/google/adk/agents/base_agent.py:295, in BaseAgent.run_async(self, parent_context)
#     292   return
#     294 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 295   async for event in agen:
#     296     yield event
#     298 if ctx.end_invocation:
#
# File /usr/local/lib/python3.11/site-packages/google/adk/agents/llm_agent.py:488, in LlmAgent._run_async_impl(self, ctx)
#     486 should_pause = False
#     487 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 488   async for event in agen:
#     489     self.__maybe_save_output_to_state(event)
#     490     yield event
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:810, in BaseLlmFlow.run_async(self, invocation_context)
#     808 last_event = None
#     809 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 810   async for event in agen:
#     811     last_event = event
#     812     yield event
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:897, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     887 async for llm_response in agen:
#     888   # Postprocess after calling the LLM.
#     889   async with Aclosing(
#     890       self._postprocess_async(
#     891           invocation_context,
#    (...)    895       )
#     896   ) as agen:
# --> 897     async for event in agen:
#     898       # Update the mutable event id to avoid conflict
#     899       model_response_event.id = Event.new_id()
#     900       model_response_event.timestamp = platform_time.get_time()
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:990, in BaseLlmFlow._postprocess_async(self, invocation_context, llm_request, llm_response, model_response_event)
#     983   return
#     985 async with Aclosing(
#     986     self._postprocess_handle_function_calls_async(
#     987         invocation_context, model_response_event, llm_request
#     988     )
#     989 ) as agen:
# --> 990   async for event in agen:
#     991     yield event
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1117, in BaseLlmFlow._postprocess_handle_function_calls_async(self, invocation_context, function_call_event, llm_request)
#    1111 async def _postprocess_handle_function_calls_async(
#    1112     self,
#    1113     invocation_context: InvocationContext,
#    1114     function_call_event: Event,
#    1115     llm_request: LlmRequest,
#    1116 ) -> AsyncGenerator[Event, None]:
# -> 1117   if function_response_event := await functions.handle_function_calls_async(
#    1118       invocation_context, function_call_event, llm_request.tools_dict
#    1119   ):
#    1120     auth_event = functions.generate_auth_event(
#    1121         invocation_context, function_response_event
#    1122     )
#    1123     if auth_event:
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:358, in handle_function_calls_async(invocation_context, function_call_event, tools_dict, filters, tool_confirmation_dict)
#     356 """Calls the functions and returns the function response event."""
#     357 function_calls = function_call_event.get_function_calls()
# --> 358 return await handle_function_call_list_async(
#     359     invocation_context,
#     360     function_calls,
#     361     tools_dict,
#     362     filters,
#     363     tool_confirmation_dict,
#     364 )
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:405, in handle_function_call_list_async(invocation_context, function_calls, tools_dict, filters, tool_confirmation_dict)
#     403 # Wait for all tasks to complete
#     404 try:
# --> 405   function_response_events = await asyncio.gather(*tasks)
#     406 except Exception:
#     407   for t in tasks:
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:598, in _execute_single_function_call_async(invocation_context, function_call, tools_dict, agent, tool_confirmation)
#     593   return function_response_event
#     595 async with _instrumentation.record_tool_execution(
#     596     tool, agent, invocation_context, function_args
#     597 ) as tel_ctx:
# --> 598   tel_ctx.function_response_event = await _run_with_trace()
#     599   return tel_ctx.function_response_event
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:546, in _execute_single_function_call_async.<locals>._run_with_trace()
#     544       function_response = error_response
#     545     else:
# --> 546       raise tool_error
#     548 # Step 4: Check if plugin after_tool_callback overrides the function
#     549 # response.
#     550 altered_function_response = (
#     551     await invocation_context.plugin_manager.run_after_tool_callback(
#     552         tool=tool,
#    (...)    556     )
#     557 )
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:533, in _execute_single_function_call_async.<locals>._run_with_trace()
#     531 if function_response is None:
#     532   try:
# --> 533     function_response = await __call_tool_async(
#     534         tool, args=function_args, tool_context=tool_context
#     535     )
#     536   except Exception as tool_error:
#     537     error_response = await _run_on_tool_error_callbacks(
#     538         tool=tool,
#     539         tool_args=function_args,
#     540         tool_context=tool_context,
#     541         error=tool_error,
#     542     )
#
# File /usr/local/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:1103, in __call_tool_async(tool, args, tool_context)
#    1097 async def __call_tool_async(
#    1098     tool: BaseTool,
#    1099     args: dict[str, Any],
#    1100     tool_context: ToolContext,
#    1101 ) -> Any:
#    1102   """Calls the tool."""
# -> 1103   return await tool.run_async(args=args, tool_context=tool_context)
#
# File /usr/local/lib/python3.11/site-packages/google/adk/tools/function_tool.py:221, in FunctionTool.run_async(self, args, tool_context)
#     218   elif not tool_context.tool_confirmation.confirmed:
#     219     return {'error': 'This tool call is rejected.'}
# --> 221 return await self._invoke_callable(self.func, args_to_call)
#
# File /usr/local/lib/python3.11/site-packages/google/adk/tools/function_tool.py:238, in FunctionTool._invoke_callable(self, target, args_to_call)
#     236   return await target(**args_to_call)
#     237 else:
# --> 238   return target(**args_to_call)
#
# File ~/work/L6/helper.py:232, in make_display_tool.<locals>.wrapper(*args, **kwargs)
#     230 print(f"\n>> {fn.__name__}")
#     231 start = time.time()
# --> 232 result = fn(*args, **kwargs)
#     233 elapsed = time.time() - start
#     234 print(f"   Done in {elapsed:.1f}s")
#
# Cell In[12], line 59, in generate_scene_video(image_path, prompt, narration, voice_profile, scene_num, timeout)
#      55         print("  Processing..."f" ({elapsed}s elapsed)")
#      56
#      57     video = (
#      58         operation.result
# ---> 59         .generated_videos[0]
#      60     )
#      61     path = f"scene_{scene_num}.mp4"
#      62     with open(path, "wb") as f:
#
# AttributeError: 'NoneType' object has no attribute 'generated_videos'

# %% [markdown]
# ## Final Step: Concatenate with ffmpeg

# %%
with open("scenes.txt", "w") as f:
    f.write("file 'scene_1.mp4'\n")
    f.write("file 'scene_2.mp4'\n")
    f.write("file 'scene_3.mp4'\n")

# !ffmpeg -f concat -safe 0 -i scenes.txt -c copy rag_explainer.mp4 -y -loglevel error

print("Final video: rag_explainer.mp4")

display(Video("rag_explainer.mp4", embed=True, width=800, height=450))

# %% [markdown]
# **Resources**
# - [Agent Development Kit](https://google.github.io/adk-docs/)
# - [Veo documentation](https://cloud.google.com/vertex-ai/generative-ai/docs/video/overview)
